# %%
import random
import pandas as pd

L=[[1,1,3],
   [2,1,2],
   [3,1,1],
   [4,2,5],
   [5,2,3],
   [6,3,2],
   [7,3,5],
   [8,3,2],
   [9,3,1],
   [10,3,1]]

t=[[0,1,2,3],
   [1,0,1,3],
   [2,1,0,2],
   [3,3,2,0]]

t=pd.DataFrame(t)
df = pd.DataFrame(L, columns = ['Pompe', 'Usine','Travail'])
df=df.sort_values(by=['Usine', 'Travail'])

groups = [df for _, df in df.groupby('Usine')]
random.shuffle(groups)
shuffled = pd.concat(groups).reset_index(drop=True)
print(shuffled)

capa=8
charge =0
nbequipes=1
e=[]
usineactuel=0
s=len(shuffled.index) 

for i in range(s):
    pompe=shuffled.iloc[0,0]
    usinesuiv=shuffled.iloc[0,1]
    prev=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    if prev>capa:
        globals()['equipe'+str(nbequipes)+'pompes']=e
        globals()['equipe'+str(nbequipes)+'charge']=charge 
        print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e))
        print('L\'équipe '+str(nbequipes)+' a une charge de '+str(charge))
        e=[]
        nbequipes=nbequipes+1
        charge =0
        usineactuel=0
    charge=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    e.append(pompe)
    shuffled.drop(labels=i, inplace=True)
    s=len(shuffled.index)  
    usineactuel=usinesuiv

print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e))
print('L\'équipe '+str(nbequipes)+' a une charge de '+str(charge))

# %%
import random
import pandas as pd

L=[[1,1,3],
   [2,1,2],
   [3,1,1],
   [4,2,5],
   [5,2,3],
   [6,3,2],
   [7,3,5],
   [8,3,2],
   [9,3,1],
   [10,3,1]]

t=[[0,1,2,3],
   [1,0,1,3],
   [2,1,0,2],
   [3,3,2,0]]

t=pd.DataFrame(t)
df = pd.DataFrame(L, columns = ['Pompe', 'Usine','Travail'])
df=df.sort_values(by=['Usine', 'Travail'])

groups = [df for _, df in df.groupby('Usine')]
random.shuffle(groups)
shuffled = pd.concat(groups).reset_index(drop=True)
print(shuffled)

capa=8
charge =0
nbequipes=1
e=[]
usineactuel=0
s=len(shuffled.index) 

while s>0:
    pompe=shuffled.iloc[0,0]
    usinesuiv=shuffled.iloc[0,1]
    prev=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    if prev>capa:
        U=shuffled["Usine"].nunique()
        if U>1:
            tel = shuffled[shuffled["Usine"] != usineactuel].index.tolist()
            tel=tel[0]
            testpompe = shuffled.iloc[tel,0]
            testcharge = shuffled.iloc[tel,2]
            testusine = shuffled.iloc[tel,1]
            tempsprev = charge + testcharge + t.iloc[usineactuel,testusine]
            if tempsprev<capa:
                e.append(testpompe)
                shuffled.drop(labels=tel, inplace=True)
                shuffled.index = range(len(shuffled)) 
                s=len(shuffled.index) 
                usineactuel=testusine
            tel=[]
        globals()['equipe'+str(nbequipes)+'pompes']=e
        globals()['equipe'+str(nbequipes)+'charge']=charge 
        print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
        e=[]
        nbequipes=nbequipes+1
        charge =0
        usineactuel=0
    charge=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    e.append(pompe)
    shuffled.drop(labels=0, inplace=True)
    shuffled.index = range(len(shuffled)) 
    s=len(shuffled.index)  
    usineactuel=usinesuiv

print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
# Out:
#    Pompe  Usine  Travail
# 0      5      2        3
# 1      4      2        5
# 2      9      3        1
# 3     10      3        1
# 4      6      3        2
# 5      8      3        2
# 6      7      3        5
# 7      3      1        1
# 8      2      1        2
# 9      1      1        3
# L'équipe 1 visite les pompes[5]et a une charge de travail de 5
# L'équipe 2 visite les pompes[4]et a une charge de travail de 7
# L'équipe 3 visite les pompes[9, 10, 6]et a une charge de travail de 7
# L'équipe 4 visite les pompes[8]et a une charge de travail de 5
# L'équipe 5 visite les pompes[7]et a une charge de travail de 8
# L'équipe 6 visite les pompes[3, 2, 1]et a une charge de travail de 7

# %%
import random
import pandas as pd

L=[[1,1,3],
   [2,1,1],
   [3,1,1],
   [4,2,5],
   [5,2,3],
   [6,3,2],
   [7,3,5],
   [8,3,2],
   [9,3,1],
   [10,3,1]]

t=[[0,1,2,3],
   [1,0,1,3],
   [2,1,0,2],
   [3,3,2,0]]

t=pd.DataFrame(t)
df = pd.DataFrame(L, columns = ['Pompe', 'Usine','Travail'])
df=df.sort_values(by=['Usine', 'Travail'])

groups = [df for _, df in df.groupby('Usine')]
random.shuffle(groups)
shuffled = pd.concat(groups).reset_index(drop=True)
print(shuffled)

capa=8
charge =0
nbequipes=1
e=[]
usineactuel=0
s=len(shuffled.index) 
affect=0
asupr=[]

while s>0:
    pompe=shuffled.iloc[0,0]
    usinesuiv=shuffled.iloc[0,1]
    prev=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    if prev>capa:
        U=shuffled["Usine"].nunique()
        if U>1:
            tel = shuffled[shuffled["Usine"] != usineactuel].index.tolist()
            tel=list(tel)
            for i in tel:
                testpompe = shuffled.iloc[i,0]
                testcharge = shuffled.iloc[i,2]
                testusine = shuffled.iloc[i,1]
                tempsprev = charge + testcharge + t.iloc[usineactuel,testusine]
                if tempsprev<=capa:
                    e.append(testpompe)
                    s=len(shuffled.index) 
                    usineactuel=testusine
                    U=shuffled["Usine"].nunique()
                    charge=tempsprev
                    asupr.append(i)
        shuffled.drop(labels=asupr, inplace=True)
        shuffled.index = range(len(shuffled))
        asupr=[]
        globals()['equipe'+str(nbequipes)+'pompes']=e
        globals()['equipe'+str(nbequipes)+'charge']=charge 
        print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
        e=[]
        nbequipes=nbequipes+1
        charge =0
        usineactuel=0
    charge=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    e.append(pompe)
    shuffled.drop(labels=0, inplace=True)
    shuffled.index = range(len(shuffled)) 
    s=len(shuffled.index)  
    usineactuel=usinesuiv

print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
# Out:
#    Pompe  Usine  Travail
# 0      5      2        3
# 1      4      2        5
# 2      9      3        1
# 3     10      3        1
# 4      6      3        2
# 5      8      3        2
# 6      7      3        5
# 7      2      1        1
# 8      3      1        1
# 9      1      1        3
# L'équipe 1 visite les pompes[5, 9]et a une charge de travail de 8
# L'équipe 2 visite les pompes[4]et a une charge de travail de 7
# L'équipe 3 visite les pompes[10, 6, 8]et a une charge de travail de 8
# L'équipe 4 visite les pompes[7]et a une charge de travail de 8
# L'équipe 5 visite les pompes[2, 3, 1]et a une charge de travail de 6

# %%
import random
import pandas as pd

    
L=[[1,1,3],
   [2,1,1],
   [3,1,1],
   [4,2,5],
   [5,2,3],
   [6,3,2],
   [7,3,5],
   [8,3,2],
   [9,3,1],
   [10,3,1]]

t=[[0,1,2,3],
   [1,0,1,3],
   [2,1,0,2],
   [3,3,2,0]]

t=pd.DataFrame(t)
df = pd.DataFrame(L, columns = ['Pompe', 'Usine','Travail'])
df=df.sort_values(by=['Usine', 'Travail'],ascending=False)

groups = [df for _, df in df.groupby('Usine')]
random.shuffle(groups)
shuffled = pd.concat(groups).reset_index(drop=True)
#print(shuffled)

capa=8
charge =0
nbequipes=1
e=[]
usineactuel=0
s=len(shuffled.index) 
affect=0
asupr=[]
mem=[]

while s>0:
    pompe=shuffled.iloc[0,0]
    usinesuiv=shuffled.iloc[0,1]
    prev=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    if prev>capa:
        U=shuffled["Usine"].nunique()
        if U>1:
            tel = shuffled[shuffled["Usine"] != usineactuel].index.tolist()
            tel=list(tel)
            for i in tel:
                testpompe = shuffled.iloc[i,0]
                testcharge = shuffled.iloc[i,2]
                testusine = shuffled.iloc[i,1]
                tempsprev = charge + testcharge + t.iloc[usineactuel,testusine]
                if tempsprev<=capa:
                    e.append(testpompe)
                    s=len(shuffled.index) 
                    usineactuel=testusine
                    U=shuffled["Usine"].nunique()
                    charge=tempsprev
                    asupr.append(i)
        shuffled.drop(labels=asupr, inplace=True)
        shuffled.index = range(len(shuffled))
        asupr=[]
        globals()['equipe'+str(nbequipes)+'pompes']=e
        globals()['equipe'+str(nbequipes)+'charge']=charge 
        print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
        e=[]
        nbequipes=nbequipes+1
        charge =0
        usineactuel=0
    charge=charge+shuffled.iloc[0,2]+t.iloc[usineactuel,usinesuiv]
    e.append(pompe)
    shuffled.drop(labels=0, inplace=True)
    shuffled.index = range(len(shuffled)) 
    s=len(shuffled.index)  
    usineactuel=usinesuiv

print('L\'équipe '+str(nbequipes)+' visite les pompes'+str(e)+'et a une charge de travail de '+str(charge))
# Out:
# L'équipe 1 visite les pompes[7]et a une charge de travail de 8
# L'équipe 2 visite les pompes[6, 8, 9]et a une charge de travail de 8
# L'équipe 3 visite les pompes[10, 2]et a une charge de travail de 8
# L'équipe 4 visite les pompes[1, 3]et a une charge de travail de 5
# L'équipe 5 visite les pompes[4]et a une charge de travail de 7
# L'équipe 6 visite les pompes[5]et a une charge de travail de 5
